# %%
import os, sys
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

import joblib

from utils import print_results

# %%
alpha = 0.1
data = joblib.load(f"results/alpha={alpha}.joblib")

# %%
print_results(data[0]['methods']['up-ocp'])
# Out:
# ============================================================
# COVERAGE
# ============================================================
# Overall coverage:  0.8928  (target: 0.95)
#
# ============================================================
# WORST GROUPS (by |coverage - target|)
# ============================================================
#  1. group=7    coverage=0.8641  gap=0.0359  count=3731
#  2. group=3    coverage=0.8702  gap=0.0298  count=994
#  3. group=10   coverage=0.8766  gap=0.0234  count=794
#  4. group=5    coverage=0.8802  gap=0.0198  count=3889
#  5. group=11   coverage=0.8875  gap=0.0125  count=2764
#
# ============================================================
# LONGEST ERROR SEQUENCE
# ============================================================
# Longest consecutive miscoverage (marginal): 5
# Longest consecutive miscoverage (within a group): 5  (group: 0)
#
# ============================================================
# SET SIZE (TAU) STATISTICS
# ============================================================
# Tau: mean=4.9171, median=4.7688, q75=5.5570, q90=6.4584, q95=6.4584

# %%
print_results(data[0]['methods']['pogo'])
# Out:
# ============================================================
# COVERAGE
# ============================================================
# Overall coverage:  0.8920  (target: 0.95)
#
# ============================================================
# WORST GROUPS (by |coverage - target|)
# ============================================================
#  1. group=3    coverage=0.8702  gap=0.0298  count=994
#  2. group=10   coverage=0.8715  gap=0.0285  count=794
#  3. group=7    coverage=0.8805  gap=0.0195  count=3731
#  4. group=5    coverage=0.8812  gap=0.0188  count=3889
#  5. group=11   coverage=0.8821  gap=0.0179  count=2764
#
# ============================================================
# LONGEST ERROR SEQUENCE
# ============================================================
# Longest consecutive miscoverage (marginal): 5
# Longest consecutive miscoverage (within a group): 5  (group: 0)
#
# ============================================================
# SET SIZE (TAU) STATISTICS
# ============================================================
# Tau: mean=4.9438, median=4.7398, q75=5.6210, q90=6.6206, q95=6.6206

# %%
print_results(data[0]['methods']['gcaci'])
# Out:
# ============================================================
# COVERAGE
# ============================================================
# Overall coverage:  0.9000  (target: 0.95)
#
# ============================================================
# WORST GROUPS (by |coverage - target|)
# ============================================================
#  1. group=10   coverage=0.8980  gap=0.0020  count=794
#  2. group=3    coverage=0.8984  gap=0.0016  count=994
#  3. group=5    coverage=0.8995  gap=0.0005  count=3889
#  4. group=8    coverage=0.8995  gap=0.0005  count=995
#  5. group=6    coverage=0.9004  gap=0.0004  count=6947
#
# ============================================================
# LONGEST ERROR SEQUENCE
# ============================================================
# Longest consecutive miscoverage (marginal): 4
# Longest consecutive miscoverage (within a group): 4  (group: 0)
#
# ============================================================
# SET SIZE (TAU) STATISTICS
# ============================================================
# Tau: mean=6.5041, median=6.3000, q75=8.3000, q90=10.3000, q95=10.3000
