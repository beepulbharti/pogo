# %%
import os, sys
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

import joblib

from utils import print_results

# %%
stock = "DAL"
alpha = 0.1
data = joblib.load(f"results/{stock}/alpha={alpha}.joblib")

# %%
print_results(data[0]['methods']['up-ocp'])
# Out:
# ...
# COVERAGE
# ...
# Overall coverage:  0.8835  (target: 0.95)
#
# ...
# WORST GROUPS (by |coverage - target|)
# ...
#  1. group=24   coverage=0.8523  gap=0.0477  count=264
#  2. group=37   coverage=0.8525  gap=0.0475  count=244
#  3. group=14   coverage=0.8631  gap=0.0369  count=263
#  4. group=18   coverage=0.8740  gap=0.0260  count=254
#  5. group=43   coverage=0.8743  gap=0.0257  count=167
#
# ...
# LONGEST ERROR SEQUENCE
# ...
# Longest consecutive miscoverage (marginal): 6
# Longest consecutive miscoverage (within a group): 6  (group: 0)
#
# ...
# SET SIZE (TAU) STATISTICS
# ...
# Tau: mean=4.1258, median=3.6071, q75=4.8327, q90=6.7977, q95=6.7977

# %%
print_results(data[0]['methods']['pogo'])
# Out:
# ...
# COVERAGE
# ...
# Overall coverage:  0.8804  (target: 0.95)
#
# ...
# WORST GROUPS (by |coverage - target|)
# ...
#  1. group=37   coverage=0.8443  gap=0.0557  count=244
#  2. group=24   coverage=0.8447  gap=0.0553  count=264
#  3. group=39   coverage=0.9431  gap=0.0431  count=211
#  4. group=14   coverage=0.8669  gap=0.0331  count=263
#  5. group=44   coverage=0.8671  gap=0.0329  count=158
#
# ...
# LONGEST ERROR SEQUENCE
# ...
# Longest consecutive miscoverage (marginal): 5
# Longest consecutive miscoverage (within a group): 5  (group: 0)
#
# ...
# SET SIZE (TAU) STATISTICS
# ...
# Tau: mean=4.0945, median=3.4952, q75=4.9428, q90=6.9582, q95=6.9582

# %%
print_results(data[0]['methods']['gcaci'])
# Out:
# ...
# COVERAGE
# ...
# Overall coverage:  0.8990  (target: 0.95)
#
# ...
# WORST GROUPS (by |coverage - target|)
# ...
#  1. group=18   coverage=0.8898  gap=0.0102  count=254
#  2. group=16   coverage=0.8944  gap=0.0056  count=284
#  3. group=19   coverage=0.9051  gap=0.0051  count=253
#  4. group=44   coverage=0.9051  gap=0.0051  count=158
#  5. group=43   coverage=0.9042  gap=0.0042  count=167
#
# ...
# LONGEST ERROR SEQUENCE
# ...
# Longest consecutive miscoverage (marginal): 2
# Longest consecutive miscoverage (within a group): 2  (group: 0)
#
# ...
# SET SIZE (TAU) STATISTICS
# ...
# Tau: mean=5.8028, median=5.5000, q75=7.6000, q90=9.8000, q95=9.8000
